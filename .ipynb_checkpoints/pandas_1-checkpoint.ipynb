# %%
import pandas as pd
df = pd.read_csv('C:/Users/Dell/Downloads/insurance.csv')
df
# Out:
#        age     sex   bmi  children smoker     region  expenses
# 0     19.0  female  27.9         0    yes  southwest  16884.92
# 1     18.0    male  33.8         1     no  southeast   1725.55
# 2     28.0    male  33.0         3     no  southeast   4449.46
# 3     33.0    male  22.7         0     no  northwest  21984.47
# 4     32.0    male  28.9         0     no  northwest   3866.86
# ...    ...     ...   ...       ...    ...        ...       ...
# 1333  50.0    male  31.0         3     no  northwest  10600.55
# 1334  18.0  female  31.9         0     no  northeast   2205.98
# 1335  18.0  female  36.9         0     no  southeast   1629.83
# 1336  21.0  female  25.8         0     no  southwest   2007.95
# 1337  61.0  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# max age
df['age'].max()
# Out:
# 64.0

# %%
#retrive age when bmi>25
df['age'][df['bmi']>25]
# Out:
# 0       19.0
# 1       18.0
# 2       28.0
# 4       32.0
# 5       31.0
#         ...
# 1333    50.0
# 1334    18.0
# 1335    18.0
# 1336    21.0
# 1337    61.0
# Name: age, Length: 1091, dtype: float64

# %%
df['age'].mean()
# Out:
# 39.21765145848916

# %%
# put 0 in blank space 
df.fillna(0,inplace=True)
df['age'].mean()
# Out:
# 39.18834080717489

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book1.csv')
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
data = {
    'country' : ['India', "Brazil"],
    'rank' : [2, 3]
}
df = pd.DataFrame(data)
df                                             #creating dataframe
# Out:
#   country  rank
# 0   India     2
# 1  Brazil     3

# %%
df.shape
# Out:
# (2, 2)

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book1.csv')
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
df.shape
# Out:
# (7, 7)

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.head(2)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55

# %%
df.tail(2)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
df[2:5] #print 2 to 5 rows
# Out:
#    age   sex   bmi  children smoker     region  expenses
# 2   28  male  33.0         3     no  southeast   4449.46
# 3   33  male  22.7         0     no  northwest  21984.47
# 4   32  male  28.9         0     no  northwest   3866.86

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.age  #df['Age']
# Out:
# 0    19
# 1    18
# 2    28
# 3    33
# 4    32
# 5    31
# 6    46
# Name: age, dtype: int64

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df[['age', 'sex']]
# Out:
#    age     sex
# 0   19  female
# 1   18    male
# 2   28    male
# 3   33    male
# 4   32    male
# 5   31  female
# 6   46  female

# %%
print('operation')
# Out:
# operation

# %%
df['age'].max()
# Out:
# 46

# %%
df['age'].min()
# Out:
# 18

# %%
df.describe()
# Out:
#              age        bmi  children      expenses
# count   7.000000   7.000000  7.000000      7.000000
# mean   29.571429  29.342857  0.714286   8701.210000
# std     9.466734   4.269605  1.112697   7726.441581
# min    18.000000  22.700000  0.000000   1725.550000
# 25%    23.500000  26.800000  0.000000   3811.740000
# 50%    31.000000  28.900000  0.000000   4449.460000
# 75%    32.500000  33.200000  1.000000  12562.755000
# max    46.000000  33.800000  3.000000  21984.470000

# %%
#conditionally select data
df[df.age>33]
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
df[df.age == df['age'].max()]
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
df[['sex', 'age']][df.age==df['age'].max()] #print sex when age is max
# Out:
#       sex  age
# 6  female   46

# %% [raw]
# df.reset_index[inplace=True]
# df

# %%
df
# Out:
#          bmi  children smoker     region  expenses
# sex
# female  27.9         0    yes  southwest  16884.92
# male    33.8         1     no  southeast   1725.55
# male    33.0         3     no  southeast   4449.46
# male    22.7         0     no  northwest  21984.47
# male    28.9         0     no  northwest   3866.86
# female  25.7         0     no  southeast   3756.62
# female  33.4         1     no  southeast   8240.59

# %%
df.reset_index()
# Out:
#       sex   bmi  children smoker     region  expenses
# 0  female  27.9         0    yes  southwest  16884.92
# 1    male  33.8         1     no  southeast   1725.55
# 2    male  33.0         3     no  southeast   4449.46
# 3    male  22.7         0     no  northwest  21984.47
# 4    male  28.9         0     no  northwest   3866.86
# 5  female  25.7         0     no  southeast   3756.62
# 6  female  33.4         1     no  southeast   8240.59

# %%
df
# Out:
#          bmi  children smoker     region  expenses
# sex
# female  27.9         0    yes  southwest  16884.92
# male    33.8         1     no  southeast   1725.55
# male    33.0         3     no  southeast   4449.46
# male    22.7         0     no  northwest  21984.47
# male    28.9         0     no  northwest   3866.86
# female  25.7         0     no  southeast   3756.62
# female  33.4         1     no  southeast   8240.59

# %%
df.reset_index(inplace=True)
df
# Out:
#    index     sex   bmi  children smoker     region  expenses
# 0      0  female  27.9         0    yes  southwest  16884.92
# 1      1    male  33.8         1     no  southeast   1725.55
# 2      2    male  33.0         3     no  southeast   4449.46
# 3      3    male  22.7         0     no  northwest  21984.47
# 4      4    male  28.9         0     no  northwest   3866.86
# 5      5  female  25.7         0     no  southeast   3756.62
# 6      6  female  33.4         1     no  southeast   8240.59

# %%
df.set_index('sex')
# Out:
#         level_0  index   bmi  children smoker     region  expenses
# sex
# female        0      0  27.9         0    yes  southwest  16884.92
# male          1      1  33.8         1     no  southeast   1725.55
# male          2      2  33.0         3     no  southeast   4449.46
# male          3      3  22.7         0     no  northwest  21984.47
# male          4      4  28.9         0     no  northwest   3866.86
# female        5      5  25.7         0     no  southeast   3756.62
# female        6      6  33.4         1     no  southeast   8240.59

# %%
df
# Out:
#    level_0  index     sex   bmi  children smoker     region  expenses
# 0        0      0  female  27.9         0    yes  southwest  16884.92
# 1        1      1    male  33.8         1     no  southeast   1725.55
# 2        2      2    male  33.0         3     no  southeast   4449.46
# 3        3      3    male  22.7         0     no  northwest  21984.47
# 4        4      4    male  28.9         0     no  northwest   3866.86
# 5        5      5  female  25.7         0     no  southeast   3756.62
# 6        6      6  female  33.4         1     no  southeast   8240.59

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book1.csv')
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
df.set_index('expenses', inplace=True)

# %%
df
# Out:
#            bmi  children smoker     region
# expenses
# 16884.92  27.9         0    yes  southwest
# 1725.55   33.8         1     no  southeast
# 4449.46   33.0         3     no  southeast
# 21984.47  22.7         0     no  northwest
# 3866.86   28.9         0     no  northwest
# 3756.62   25.7         0     no  southeast
# 8240.59   33.4         1     no  southeast

# %%
df.loc[1725.55]
# Out:
# bmi              33.8
# children            1
# smoker             no
# region      southeast
# Name: 1725.55, dtype: object

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book1.csv')
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
# dataframe is usig tuple
data= [
    ('India',2),
    ('Brazil',4)
]
df = pd.DataFrame(data, columns=['country','Rank'])
df
# Out:
#   country  Rank
# 0   India     2
# 1  Brazil     4

# %%
#dataframe using dictionary list
data = [
    {'country' : 'India', 'Rank' : 2},
    {'country' : 'Brazil', 'Rank' : 5}
]
df = pd.DataFrame(data)
df
# Out:
#   country  Rank
# 0   India     2
# 1  Brazil     5

# %%
#reading and writing excel csv file
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv')
df
# Out:
#   Insurance Data Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            age        sex        bmi   children     smoker     region
# 1             19     female       27.9          0        yes  southwest
# 2             18       male       33.8          1         no  southeast
# 3             28       male         33          3         no  southeast
# 4             33       male       22.7          0         no  northwest
# 5             32       male       28.9          0         no  northwest
# 6             31     female       25.7          0         no  southeast
# 7             46     female       33.4          1         no  southeast
#
#   Unnamed: 6
# 0   expenses
# 1   16884.92
# 2    1725.55
# 3    4449.46
# 4   21984.47
# 5    3866.86
# 6    3756.62
# 7    8240.59

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', skiprows=1)
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
#if we are not having then hedaer=None use this

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', header=None, skiprows=1)
df
# Out:
#      0       1     2         3       4          5         6
# 0  age     sex   bmi  children  smoker     region  expenses
# 1   19  female  27.9         0     yes  southwest  16884.92
# 2   18    male  33.8         1      no  southeast   1725.55
# 3   28    male    33         3      no  southeast   4449.46
# 4   33    male  22.7         0      no  northwest  21984.47
# 5   32    male  28.9         0      no  northwest   3866.86
# 6   31  female  25.7         0      no  southeast   3756.62
# 7   46  female  33.4         1      no  southeast   8240.59

# %%
#to give header
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', header=None, names=['age','sex','bmi','children','smoker','region','expenses'], skiprows=1)
df
# Out:
#    age     sex   bmi  children  smoker     region  expenses
# 0  age     sex   bmi  children  smoker     region  expenses
# 1   19  female  27.9         0     yes  southwest  16884.92
# 2   18    male  33.8         1      no  southeast   1725.55
# 3   28    male    33         3      no  southeast   4449.46
# 4   33    male  22.7         0      no  northwest  21984.47
# 5   32    male  28.9         0      no  northwest   3866.86
# 6   31  female  25.7         0      no  southeast   3756.62
# 7   46  female  33.4         1      no  southeast   8240.59

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', skiprows=1)
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
#no.of you want to read
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', skiprows=1,nrows=4)
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', skiprows=1)
df
# Out:
#    age     sex            bmi  children         smoker     region  expenses
# 0   19  female           27.9         0            yes  southwest  16884.92
# 1   18    male           33.8         1             no  southeast   1725.55
# 2   28    male             33         3  not available  southeast   4449.46
# 3   33    male           22.7         0             no  northwest  21984.47
# 4   32    male  not available         0             no  northwest   3866.86
# 5   31  female           25.7         0             no  southeast   3756.62
# 6   46  female           33.4         1             no  southeast   8240.59

# %%
#convert not avialble or na to NaN
df = pd.read_csv('C:/Users/Dell/Desktop/1/Book2.csv', skiprows=1, na_values=['not available','na'])
df
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3    NaN  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male   NaN         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Dell/Downloads/insurance.csv')
df
# Out:
#        age     sex   bmi  children smoker     region  expenses
# 0     19.0  female  27.9         0    yes  southwest  16884.92
# 1     18.0    male  33.8         1     no  southeast   1725.55
# 2     28.0    male  33.0         3     no  southeast   4449.46
# 3     33.0    male  22.7         0     no  northwest  21984.47
# 4     32.0    male  28.9         0     no  northwest   3866.86
# ...    ...     ...   ...       ...    ...        ...       ...
# 1333  50.0    male  31.0         3     no  northwest  10600.55
# 1334  18.0  female  31.9         0     no  northeast   2205.98
# 1335  18.0  female  36.9         0     no  southeast   1629.83
# 1336  21.0  female  25.8         0     no  southwest   2007.95
# 1337  61.0  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.to_csv('new.csv', index=False)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.to_csv('new.csv', columns=['age', 'sex']) #this 2 column only print

# %%
df.to_csv('new.csv', header=False) #remove header

# %%
df = pd.read_excel('C:/Users/Dell/Desktop/1/Book3.xlsx', 'Sheet1')
df
# Out:
#       Group             Member Name          M.No  cast  Unnamed: 4  \
# 0          11                    22  3.300000e+01    44         NaN
# 1    Group -1        Vadhel Kashyap  6.156486e+08   obc         NaN
# 2         NaN          Joshi Maulik  1.556500e+04    na         NaN
# 3         NaN        Desai aniruddh  5.616510e+05    na         NaN
# 4         NaN        Karena Kishan   5.665650e+05   gen         NaN
# 5         NaN        Ladva Jaydeep   5.656500e+04   obc         NaN
# 6         NaN                 Miral  5.565600e+04    sc         NaN
# 7         NaN     Gohil Kuldeepsinh  5.156000e+03   gen         NaN
# 8   Group - 2     Ghelani Sanskruti  6.465446e+06   gen         NaN
# 9         NaN           Patel Sweta  4.564668e+07    na         NaN
# 10   Group -3  Mohammad kaif Saiyad  5.515646e+09   obc         NaN
# 11        NaN       Devaliya Hardik  4.500000e+01   obc         NaN
# 12        NaN      Khoshiyar Hemang  4.654654e+06    sc         NaN
# ...

# %%
df.head()
# Out:
#     Group       Member Name         M.No cast  Unnamed: 4  Unnamed: 5
# 0        11              22         33.0   44         NaN         NaN
# 1  Group -1  Vadhel Kashyap  615648561.0  obc         NaN         NaN
# 2       NaN    Joshi Maulik      15565.0   na         NaN         NaN
# 3       NaN  Desai aniruddh     561651.0   na         NaN         NaN
# 4       NaN  Karena Kishan      566565.0  gen         NaN         NaN

# %%
#converter
def convert_cast_cell(cell):
    if cell == 'na':
        return 'gen'
    return cell
def convert_Mno_cell(cell):
    if cell=='not available':
        return 'sorry'
    return cell
df = pd.read_excel('C:/Users/Dell/Desktop/1/Book3.xlsx', 'Sheet1', converters = {
    'cast' : convert_cast_cell,
    'Mno' : convert_Mno_cell
})
df
# Out:
#       Group             Member Name          Mno  cast  Unnamed: 4  Unnamed: 5
# 0          11                    22           33    44         NaN         NaN
# 1    Group -1        Vadhel Kashyap    615648561   obc         NaN         NaN
# 2         NaN          Joshi Maulik        15565   gen         NaN         NaN
# 3         NaN        Desai aniruddh       561651   gen         NaN         NaN
# 4         NaN        Karena Kishan        566565   gen         NaN         NaN
# 5         NaN        Ladva Jaydeep         56565   obc         NaN         NaN
# 6         NaN                 Miral        55656    sc         NaN         NaN
# 7         NaN     Gohil Kuldeepsinh         5156   gen         NaN         NaN
# 8   Group - 2     Ghelani Sanskruti      6465446   gen         NaN         NaN
# 9         NaN           Patel Sweta     45646684   gen         NaN         NaN
# 10   Group -3  Mohammad kaif Saiyad   5515645645   obc         NaN         NaN
# ...

# %%
df.to_excel('new.xlsx', sheet_name='Groups', index=False, startrow=1, startcol=2)

# %%
df_data = pd.DataFrame({
    'country' : ['India', 'Brazil', 'Japan'],
    'Rank' : [2,3,5]
})

df_year = pd.DataFrame({
    'year' : [2018,2019,2020],
    'Number' : ['one', 'second', 'third']
    
})

# %%
#in 1 excel file we can create two sheets
with pd.ExcelWriter('new1.xlsx') as writer:
    df_data.to_excel(writer, sheet_name='fifa')
    df_year.to_excel(writer, sheet_name='years')

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/weather.csv')
df
# Out:
#         date  temp  wind    even
# 0   1/1/2020  32.0   6.0    Rain
# 1   1/4/2020   NaN   9.0   sunny
# 2   1/5/2020  28.0   NaN    snow
# 3   1/6/2020   NaN   7.0     NaN
# 4   1/7/2020  32.0   NaN    Rain
# 5   1/8/2020   NaN   NaN   sunny
# 6   1/9/2020   NaN   NaN     NaN
# 7  1/10/2020  34.0   8.0  cloudy
# 8  1/11/2020  40.0  12.0   sunny

# %%
type(df.date[0])
# Out:
# str

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/weather.csv', parse_dates=['date'])
df
# Out:
#         date  temp  wind    even
# 0 2020-01-01  32.0   6.0    Rain
# 1 2020-01-04   NaN   9.0   sunny
# 2 2020-01-05  28.0   NaN    snow
# 3 2020-01-06   NaN   7.0     NaN
# 4 2020-01-07  32.0   NaN    Rain
# 5 2020-01-08   NaN   NaN   sunny
# 6 2020-01-09   NaN   NaN     NaN
# 7 2020-01-10  34.0   8.0  cloudy
# 8 2020-01-11  40.0  12.0   sunny

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df = df.fillna(0)
new_df
# Out:
#         date  temp  wind    even
# 0 2020-01-01  32.0   6.0    Rain
# 1 2020-01-04   0.0   9.0   sunny
# 2 2020-01-05  28.0   0.0    snow
# 3 2020-01-06   0.0   7.0       0
# 4 2020-01-07  32.0   0.0    Rain
# 5 2020-01-08   0.0   0.0   sunny
# 6 2020-01-09   0.0   0.0       0
# 7 2020-01-10  34.0   8.0  cloudy
# 8 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.fillna({
    'temp' : 0,
    'wind' : 0,
    'even' : 'No Event'
})
new_df
# Out:
#         date  temp  wind      even
# 0 2020-01-01  32.0   6.0      Rain
# 1 2020-01-04   0.0   9.0     sunny
# 2 2020-01-05  28.0   0.0      snow
# 3 2020-01-06   0.0   7.0  No Event
# 4 2020-01-07  32.0   0.0      Rain
# 5 2020-01-08   0.0   0.0     sunny
# 6 2020-01-09   0.0   0.0  No Event
# 7 2020-01-10  34.0   8.0    cloudy
# 8 2020-01-11  40.0  12.0     sunny

# %%
new_df = df.fillna(method='bfill', axis='columns') #ffill means if i have NaN values just carry forward previous value
new_df                             #bfill means if i have NaN values just carry backward value
# Out:
#         date   temp   wind    even
# 0 2020-01-01     32      6    Rain
# 1 2020-01-04      9      9   sunny
# 2 2020-01-05     28   snow    snow
# 3 2020-01-06      7      7     NaN
# 4 2020-01-07     32   Rain    Rain
# 5 2020-01-08  sunny  sunny   sunny
# 6 2020-01-09    NaT    NaT     NaT
# 7 2020-01-10     34      8  cloudy
# 8 2020-01-11     40     12   sunny

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/weather.csv', parse_dates=['date'])
df
# Out:
#         date  temp  wind    even
# 0 2020-01-01  32.0   6.0    Rain
# 1 2020-01-04   NaN   9.0   sunny
# 2 2020-01-05  28.0   NaN    snow
# 3 2020-01-06   NaN   7.0     NaN
# 4 2020-01-07  32.0   NaN    Rain
# 5 2020-01-08   NaN   NaN   sunny
# 6 2020-01-09   NaN   NaN     NaN
# 7 2020-01-10  34.0   8.0  cloudy
# 8 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.fillna(0)
new_df
# Out:
#         date  temp  wind    even
# 0 2020-01-01  32.0   6.0    Rain
# 1 2020-01-04   0.0   9.0   sunny
# 2 2020-01-05  28.0   0.0    snow
# 3 2020-01-06   0.0   7.0       0
# 4 2020-01-07  32.0   0.0    Rain
# 5 2020-01-08   0.0   0.0   sunny
# 6 2020-01-09   0.0   0.0       0
# 7 2020-01-10  34.0   8.0  cloudy
# 8 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.fillna({
    'temp' : 0,
    'wind' : 0,
    'even' : 'NO Event'
})
new_df
# Out:
#         date  temp  wind      even
# 0 2020-01-01  32.0   6.0      Rain
# 1 2020-01-04   0.0   9.0     sunny
# 2 2020-01-05  28.0   0.0      snow
# 3 2020-01-06   0.0   7.0  NO Event
# 4 2020-01-07  32.0   0.0      Rain
# 5 2020-01-08   0.0   0.0     sunny
# 6 2020-01-09   0.0   0.0  NO Event
# 7 2020-01-10  34.0   8.0    cloudy
# 8 2020-01-11  40.0  12.0     sunny

# %%
new_df = df.fillna(method='ffill', limit=1) #copy only 1 time
new_df
# Out:
#         date  temp  wind    even
# 0 2020-01-01  32.0   6.0    Rain
# 1 2020-01-04  32.0   9.0   sunny
# 2 2020-01-05  28.0   9.0    snow
# 3 2020-01-06  28.0   7.0    snow
# 4 2020-01-07  32.0   7.0    Rain
# 5 2020-01-08  32.0   NaN   sunny
# 6 2020-01-09   NaN   NaN   sunny
# 7 2020-01-10  34.0   8.0  cloudy
# 8 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.interpolate(method='time') #fill values automate doing reading data
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-dae51a7e9104> in <module>
# ----> 1 new_df = df.interpolate(method='time') #fill values automate doing reading data
#       2 new_df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6868                 "those NaNs before interpolating."
#    6869             )
# -> 6870         new_data = obj._mgr.interpolate(
#    6871             method=method,
#    6872             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     559
#     560     def interpolate(self, **kwargs) -> "BlockManager":
# --> 561         return self.apply("interpolate", **kwargs)
#     562
# ...

# %%
df.set_index('date',inplace=True)
df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-06   NaN   7.0     NaN
# 2020-01-07  32.0   NaN    Rain
# 2020-01-08   NaN   NaN   sunny
# 2020-01-09   NaN   NaN     NaN
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.interpolate(method='time')
new_df
# Out:
#                  temp   wind    even
# date
# 2020-01-01  32.000000   6.00    Rain
# 2020-01-04  29.000000   9.00   sunny
# 2020-01-05  28.000000   8.00    snow
# 2020-01-06  30.000000   7.00     NaN
# 2020-01-07  32.000000   7.25    Rain
# 2020-01-08  32.666667   7.50   sunny
# 2020-01-09  33.333333   7.75     NaN
# 2020-01-10  34.000000   8.00  cloudy
# 2020-01-11  40.000000  12.00   sunny

# %%
new_df = df.dropna(how='all')           #droping NaN values (how="all") is used for if any column have some data and other NaN then it can't be droped

new_df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-06   NaN   7.0     NaN
# 2020-01-07  32.0   NaN    Rain
# 2020-01-08   NaN   NaN   sunny
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-06   NaN   7.0     NaN
# 2020-01-07  32.0   NaN    Rain
# 2020-01-08   NaN   NaN   sunny
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.dropna(thresh=2)  # remove rows which have 2 NaN values
new_df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-07  32.0   NaN    Rain
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.dropna(thresh=3)  #remove rows which have 3 NaN values
new_df
# Out:
#        date    temp    wind      even
# 0  1/1/2020    32.0     6.0      Rain
# 1  1/2/2020 -9999.0     9.0     sunny
# 2  1/3/2020    28.0 -9999.0      snow
# 3  1/4/2020 -9999.0     7.0  No Event
# 4  1/5/2020    32.0 -9999.0      Rain
# 5  1/6/2020    31.0     2.0     sunny
# 6  1/6/2020    34.0     5.0      rain

# %%
df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-06   NaN   7.0     NaN
# 2020-01-07  32.0   NaN    Rain
# 2020-01-08   NaN   NaN   sunny
# 2020-01-09   NaN   NaN     NaN
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
new_df = df.dropna(thresh=2)
new_df
# Out:
#             temp  wind    even
# date
# 2020-01-01  32.0   6.0    Rain
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-07  32.0   NaN    Rain
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
dt = pd.date_range('01-01-2020', '01-11-2020')
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df                                 #2020-01-02	NaN	NaN	NaN
                                  #2020-01-03	NaN	NaN	NaN  --we insert this two missing Date
# Out:
#             temp  wind    even
# 2020-01-01  32.0   6.0    Rain
# 2020-01-02   NaN   NaN     NaN
# 2020-01-03   NaN   NaN     NaN
# 2020-01-04   NaN   9.0   sunny
# 2020-01-05  28.0   NaN    snow
# 2020-01-06   NaN   7.0     NaN
# 2020-01-07  32.0   NaN    Rain
# 2020-01-08   NaN   NaN   sunny
# 2020-01-09   NaN   NaN     NaN
# 2020-01-10  34.0   8.0  cloudy
# 2020-01-11  40.0  12.0   sunny

# %%
l_df = df.fillna({
    'temp' : 0,
    'wind' : 0,
    'even' : 'No Event'
})
l_df
# Out:
#             temp  wind      even
# 2020-01-01  32.0   6.0      Rain
# 2020-01-02   0.0   0.0  No Event
# 2020-01-03   0.0   0.0  No Event
# 2020-01-04   0.0   9.0     sunny
# 2020-01-05  28.0   0.0      snow
# 2020-01-06   0.0   7.0  No Event
# 2020-01-07  32.0   0.0      Rain
# 2020-01-08   0.0   0.0     sunny
# 2020-01-09   0.0   0.0  No Event
# 2020-01-10  34.0   8.0    cloudy
# 2020-01-11  40.0  12.0     sunny

# %%
l_df = df.interpolate(method='time')
l_df
# Out:
#                  temp   wind    even
# 2020-01-01  32.000000   6.00    Rain
# 2020-01-02  31.000000   7.00     NaN
# 2020-01-03  30.000000   8.00     NaN
# 2020-01-04  29.000000   9.00   sunny
# 2020-01-05  28.000000   8.00    snow
# 2020-01-06  30.000000   7.00     NaN
# 2020-01-07  32.000000   7.25    Rain
# 2020-01-08  32.666667   7.50   sunny
# 2020-01-09  33.333333   7.75     NaN
# 2020-01-10  34.000000   8.00  cloudy
# 2020-01-11  40.000000  12.00   sunny

# %%
import  pandas as pd
df = pd.read_csv('C:/Users/Dell/Desktop/1/Weather_1.csv')
df
# Out:
#        date   temp    wind   even
# 0  1/1/2020   32 F   6 mph   Rain
# 1  1/2/2020  -9999   9 mph  sunny
# 2  1/3/2020     28   -9999   snow
# 3  1/4/2020  -9999       7      0
# 4  1/5/2020     32   -8888   Rain
# 5  1/6/2020     31       2  sunny
# 6  1/6/2020     34       5      0

# %%
import numpy as np
new_df = df.replace({
    'temp' : -9999,
    'wind' : -9999,
    'even' : '0'
},np.NaN) #we can give list as argu if we have more than one which we want to replace
new_df
# Out:
#        date  temp    wind   even
# 0  1/1/2020  32.0     6.0   Rain
# 1  1/2/2020   NaN     9.0  sunny
# 2  1/3/2020  28.0     NaN   snow
# 3  1/4/2020   NaN     7.0    NaN
# 4  1/5/2020  32.0 -8888.0   Rain
# 5  1/6/2020  31.0     2.0  sunny
# 6  1/6/2020  34.0     5.0    NaN

# %%
new_df = df.replace({
    -9999 : np.NaN,
    -8888 : np.NaN,
    '0' : 'sunny'
})
new_df
# Out:
#        date  temp  wind   even
# 0  1/1/2020  32.0   6.0   Rain
# 1  1/2/2020   NaN   9.0  sunny
# 2  1/3/2020  28.0   NaN   snow
# 3  1/4/2020   NaN   7.0  sunny
# 4  1/5/2020  32.0   NaN   Rain
# 5  1/6/2020  31.0   2.0  sunny
# 6  1/6/2020  34.0   5.0  sunny

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Weather_1.csv')
df
# Out:
#        date   temp    wind   even
# 0  1/1/2020   32 F   6 mph   Rain
# 1  1/2/2020  -9999   9 mph  sunny
# 2  1/3/2020     28   -9999   snow
# 3  1/4/2020  -9999       7      0
# 4  1/5/2020     32   -8888   Rain
# 5  1/6/2020     31       2  sunny
# 6  1/6/2020     34       5      0

# %%
new_df = df.replace({
    'temp' : '[A-Za-z]',
    'wind' : '[A-Za-z]'
    
},'',regex=True)
new_df
# Out:
#        date   temp   wind   even
# 0  1/1/2020    32      6    Rain
# 1  1/2/2020  -9999     9   sunny
# 2  1/3/2020     28  -9999   snow
# 3  1/4/2020  -9999      7      0
# 4  1/5/2020     32  -8888   Rain
# 5  1/6/2020     31      2  sunny
# 6  1/6/2020     34      5      0

# %%
#create dataframe
data = ({
    'score' : ['exceptional', 'average', 'good', 'poor', 'average'],
    'Name' : ['rob', 'tom', 'jerry', 'mickey', 'bunty']
    
})
df = pd.DataFrame(data)
df
# Out:
#          score    Name
# 0  exceptional     rob
# 1      average     tom
# 2         good   jerry
# 3         poor  mickey
# 4      average   bunty

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score    Name
# 0      4     rob
# 1      2     tom
# 2      3   jerry
# 3      1  mickey
# 4      2   bunty

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Weather_2.csv')
df
# Out:
#         date  temp  wind   even    city
# 0   1/1/2020    32     6   Rain     bvn
# 1   1/2/2020    34     9  sunny     bvn
# 2   1/3/2020    28     9   snow     bvn
# 3   1/4/2020    39     7   Rain     bvn
# 4   1/1/2020    33     7    fog     rjk
# 5   1/2/2020    32     9  sunny     rjk
# 6   1/3/2020    31     8   Rain     rjk
# 7   1/4/2020    30     7   snow     rjk
# 8   1/1/2020    33     6   Rain  gnagar
# 9   1/2/2020    35     7   snow  gnagar
# 10  1/3/2020    33     8  sunny  gnagar
# 11  1/4/2020    30     9    fog  gnagar

# %%
g = df.groupby('city').city
g

# %%
for city ,city_df in g:
    print(city)
    print(city_df)
# Out:
# bvn
#        date  temp  wind   even city
# 0  1/1/2020    32     6   Rain  bvn
# 1  1/2/2020    34     9  sunny  bvn
# 2  1/3/2020    28     9   snow  bvn
# 3  1/4/2020    39     7   Rain  bvn
# gnagar
#         date  temp  wind   even    city
# 8   1/1/2020    33     6   Rain  gnagar
# 9   1/2/2020    35     7   snow  gnagar
# 10  1/3/2020    33     8  sunny  gnagar
# 11  1/4/2020    30     9    fog  gnagar
# rjk
#        date  temp  wind   even city
# 4  1/1/2020    33     7    fog  rjk
# 5  1/2/2020    32     9  sunny  rjk
# 6  1/3/2020    31     8   Rain  rjk
# 7  1/4/2020    30     7   snow  rjk

# %%
g.get_group('bvn')
# Out:
#        date  temp  wind   even city
# 0  1/1/2020    32     6   Rain  bvn
# 1  1/2/2020    34     9  sunny  bvn
# 2  1/3/2020    28     9   snow  bvn
# 3  1/4/2020    39     7   Rain  bvn

# %%
g.max()
# Out:
#             date  temp  wind   even
# city
# bvn     1/4/2020    39     9  sunny
# gnagar  1/4/2020    35     9  sunny
# rjk     1/4/2020    33     9  sunny

# %%
g.mean()
# Out:
#          temp  wind
# city
# bvn     33.25  7.75
# gnagar  32.75  7.50
# rjk     31.50  7.75

# %%
g.describe()
# Out:
#         temp                                                   wind        \
#        count   mean       std   min    25%   50%    75%   max count  mean
# city
# bvn      4.0  33.25  4.573474  28.0  31.00  33.0  35.25  39.0   4.0  7.75
# gnagar   4.0  32.75  2.061553  30.0  32.25  33.0  33.50  35.0   4.0  7.50
# rjk      4.0  31.50  1.290994  30.0  30.75  31.5  32.25  33.0   4.0  7.75
#
#
#              std  min   25%  50%   75%  max
# city
# bvn     1.500000  6.0  6.75  8.0  9.00  9.0
# gnagar  1.290994  6.0  6.75  7.5  8.25  9.0
# rjk     0.957427  7.0  7.00  7.5  8.25  9.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
g.plot()
# Out:
# city
# bvn       AxesSubplot(0.125,0.125;0.775x0.755)
# gnagar    AxesSubplot(0.125,0.125;0.775x0.755)
# rjk       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
india_weather =pd.DataFrame ({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'temp' : [32,45,46],
    'humidity' : [60,70,80]
})
india_weather
# Out:
#      city  temp  humidity
# 0     bvn    32        60
# 1     rjk    45        70
# 2  gnagar    46        80

# %%
us_weather = pd.DataFrame({
    'city' : ['nyc', 'dc', 'chicago'],
    'temp' : [21,14,15],
    'humidity' : [70,80,89]
})
us_weather
# Out:
#       city  temp  humidity
# 0      nyc    21        70
# 1       dc    14        80
# 2  chicago    15        89

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#       city  temp  humidity
# 0      bvn    32        60
# 1      rjk    45        70
# 2   gnagar    46        80
# 0      nyc    21        70
# 1       dc    14        80
# 2  chicago    15        89

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#       city  temp  humidity
# 0      bvn    32        60
# 1      rjk    45        70
# 2   gnagar    46        80
# 3      nyc    21        70
# 4       dc    14        80
# 5  chicago    15        89

# %%
df = pd.concat([india_weather, us_weather],  keys=['india', 'us'] )
df
# Out:
#             city  temp  humidity
# india 0      bvn    32        60
#       1      rjk    45        70
#       2   gnagar    46        80
# us    0      nyc    21        70
#       1       dc    14        80
#       2  chicago    15        89

# %%
df.loc['india']
# Out:
#      city  temp  humidity
# 0     bvn    32        60
# 1     rjk    45        70
# 2  gnagar    46        80

# %%
df.loc['us']
# Out:
#       city  temp  humidity
# 0      nyc    21        70
# 1       dc    14        80
# 2  chicago    15        89

# %%
temp_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'temp' : [32,45,46]
})
temp_df
# Out:
#      city  temp
# 0     bvn    32
# 1     rjk    45
# 2  gnagar    46

# %%
wind_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'wind' : [9,7,8]
})
wind_df
# Out:
#      city  wind
# 0     bvn     9
# 1     rjk     7
# 2  gnagar     8

# %%
df = pd.concat([temp_df, wind_df])
df
# Out:
#      city  temp  wind
# 0     bvn  32.0   NaN
# 1     rjk  45.0   NaN
# 2  gnagar  46.0   NaN
# 0     bvn   NaN   9.0
# 1     rjk   NaN   7.0
# 2  gnagar   NaN   8.0

# %%
df = pd.concat([temp_df, wind_df],axis=1)
df
# Out:
#      city  temp    city  wind
# 0     bvn    32     bvn     9
# 1     rjk    45     rjk     7
# 2  gnagar    46  gnagar     8

# %%
temp_df = pd.DataFrame({
    'city' : ['rjk', 'bvn'],
    'temp' : [32,45]
})
temp_df
# Out:
#   city  temp
# 0  rjk    32
# 1  bvn    45

# %%
wind_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'wind' : [9,7,8]
})
wind_df
# Out:
#      city  wind
# 0     bvn     9
# 1     rjk     7
# 2  gnagar     8

# %%
df = pd.concat([temp_df, wind_df],axis=1)
df
# Out:
#   city  temp    city  wind
# 0  rjk  32.0     bvn     9
# 1  bvn  45.0     rjk     7
# 2  NaN   NaN  gnagar     8

# %%
temp_df = pd.DataFrame({
    'city' : ['rjk', 'bvn'],
    'temp' : [32,45]
}, index=[0,1])
temp_df
# Out:
#   city  temp
# 0  rjk    32
# 1  bvn    45

# %%
wind_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'wind' : [9,7,8]
},index=[1,0,2])
wind_df
# Out:
#      city  wind
# 1     bvn     9
# 0     rjk     7
# 2  gnagar     8

# %%
df = pd.concat([temp_df, wind_df],axis=1)
df
# Out:
#   city  temp    city  wind
# 0  rjk  32.0     rjk     7
# 1  bvn  45.0     bvn     9
# 2  NaN   NaN  gnagar     8

# %%
temp_df
# Out:
#   city  temp
# 0  rjk    32
# 1  bvn    45

# %%
s = pd.Series(['Humid','Dry', 'Rain'], name='event')
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
pd.concat([wind_df,s], axis=1)
# Out:
#      city  wind  event
# 0     rjk     7  Humid
# 1     bvn     9    Dry
# 2  gnagar     8   Rain

# %%
import pandas as pd
temp_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'temp' : [32,45,46]
})
temp_df
# Out:
#      city  temp
# 0     bvn    32
# 1     rjk    45
# 2  gnagar    46

# %%
wind_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar'],
    'wind' : [9,7,8]
})
wind_df
# Out:
#      city  wind
# 0     bvn     9
# 1     rjk     7
# 2  gnagar     8

# %%
df1 = pd.merge(temp_df, wind_df, on='city')
df1
# Out:
#      city  temp  wind
# 0     bvn    32     9
# 1     rjk    45     7
# 2  gnagar    46     8

# %%
temp_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar','ahemdabad'],
    'temp' : [32,45,46,44]
})
temp_df
# Out:
#         city  temp
# 0        bvn    32
# 1        rjk    45
# 2     gnagar    46
# 3  ahemdabad    44

# %%
wind_df = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'jamnagar'],
    'wind' : [9,7,8]
})
wind_df
# Out:
#        city  wind
# 0       bvn     9
# 1       rjk     7
# 2  jamnagar     8

# %%
df1 = pd.merge(temp_df, wind_df, on='city')
df1
# Out:
#   city  temp  wind
# 0  bvn    32     9
# 1  rjk    45     7

# %%
df1 = pd.merge(temp_df, wind_df, on='city', how='outer')
df1
# Out:
#         city  temp  wind
# 0        bvn  32.0   9.0
# 1        rjk  45.0   7.0
# 2     gnagar  46.0   NaN
# 3  ahemdabad  44.0   NaN
# 4   jamnagar   NaN   8.0

# %%
df1 = pd.merge(temp_df, wind_df, on='city', how='left')  #left= temp_df
df1
# Out:
#         city  temp  wind
# 0        bvn    32   9.0
# 1        rjk    45   7.0
# 2     gnagar    46   NaN
# 3  ahemdabad    44   NaN

# %%
df1 = pd.merge(temp_df, wind_df, on='city', how='right')  #right = wind_df
df1
# Out:
#        city  temp  wind
# 0       bvn  32.0     9
# 1       rjk  45.0     7
# 2  jamnagar   NaN     8

# %%
df1 = pd.merge(temp_df, wind_df, on='city', how='left', indicator=True)
df1
# Out:
#         city  temp  wind     _merge
# 0        bvn    32   9.0       both
# 1        rjk    45   7.0       both
# 2     gnagar    46   NaN  left_only
# 3  ahemdabad    44   NaN  left_only

# %%
df1 = pd.DataFrame({
    'city' : ['bvn', 'rjk', 'gnagar','ahemdabad'],
    'temp' : [32,45,46,44],
    'humidity' : [60,79,76,80]
})
df1
# Out:
#         city  temp  humidity
# 0        bvn    32        60
# 1        rjk    45        79
# 2     gnagar    46        76
# 3  ahemdabad    44        80

# %%
df2 = pd.DataFrame({
    'city' : ['rjk', 'gnagar','surat'],
    'temp' : [21,43,46],
    'humidity' : [64,73,70]
})
df2
# Out:
#      city  temp  humidity
# 0     rjk    21        64
# 1  gnagar    43        73
# 2   surat    46        70

# %%
pd.merge(df1,df2, on='city')
# Out:
#      city  temp_x  humidity_x  temp_y  humidity_y
# 0     rjk      45          79      21          64
# 1  gnagar      46          76      43          73

# %%
pd.merge(df1,df2, on='city',suffixes=('_left', '_right'))
# Out:
#      city  temp_left  humidity_left  temp_right  humidity_right
# 0     rjk         45             79          21              64
# 1  gnagar         46             76          43              73

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Dell/Desktop/1/Weather_2.csv')
df
# Out:
#         date  temp  wind   even    city
# 0   1/1/2020    32     6   Rain     bvn
# 1   1/2/2020    34     9  sunny     bvn
# 2   1/3/2020    28     9   snow     bvn
# 3   1/4/2020    39     7   Rain     bvn
# 4   1/1/2020    33     7    fog     rjk
# 5   1/2/2020    32     9  sunny     rjk
# 6   1/3/2020    31     8   Rain     rjk
# 7   1/4/2020    30     7   snow     rjk
# 8   1/1/2020    33     6   Rain  gnagar
# 9   1/2/2020    35     7   snow  gnagar
# 10  1/3/2020    33     8  sunny  gnagar
# 11  1/4/2020    30     9    fog  gnagar

# %%
df.pivot(index='date', columns='city')
# Out:
#          temp            wind              even
# city      bvn gnagar rjk  bvn gnagar rjk    bvn gnagar    rjk
# date
# 1/1/2020   32     33  33    6      6   7   Rain   Rain    fog
# 1/2/2020   34     35  32    9      7   9  sunny   snow  sunny
# 1/3/2020   28     33  31    9      8   8   snow  sunny   Rain
# 1/4/2020   39     30  30    7      9   7   Rain    fog   snow

# %%
df.pivot(index='date', columns='city', values='temp')
# Out:
# city      bvn  gnagar  rjk
# date
# 1/1/2020   32      33   33
# 1/2/2020   34      35   32
# 1/3/2020   28      33   31
# 1/4/2020   39      30   30

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/1/Weather_3.csv')
df
# Out:
#        date  temp  wind city
# 0  1/1/2020    32     6  bvn
# 1  1/1/2020    34     9  bvn
# 2  1/2/2020    28     9  bvn
# 3  1/2/2020    39     7  bvn
# 4  1/1/2020    33     7  rjk
# 5  1/1/2020    32     9  rjk
# 6  1/2/2020    31     8  rjk
# 7  1/2/2020    30     7  rjk

# %%
df.pivot_table(index='city',columns='date')
# Out:
#          temp              wind
# date 1/1/2020 1/2/2020 1/1/2020 1/2/2020
# city
# bvn      33.0     33.5      7.5      8.0
# rjk      32.5     30.5      8.0      7.5

# %%
df.pivot_table(index='city',columns='date',aggfunc='sum')
# Out:
#          temp              wind
# date 1/1/2020 1/2/2020 1/1/2020 1/2/2020
# city
# bvn        66       67       15       16
# rjk        65       61       16       15

# %%
df.pivot_table(index='city',columns='date', margins=True)
# Out:
#          temp                      wind
# date 1/1/2020 1/2/2020     All 1/1/2020 1/2/2020   All
# city
# bvn     33.00     33.5  33.250     7.50     8.00  7.75
# rjk     32.50     30.5  31.500     8.00     7.50  7.75
# All     32.75     32.0  32.375     7.75     7.75  7.75
